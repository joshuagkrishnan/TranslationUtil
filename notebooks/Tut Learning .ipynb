# %%
# Everything that occupies some space is an object ?

# Everything in python is a object 

# defingin method add with two args

# operators :: + - * / % 

# conditions :: > , <, >=, <= , ==

def add(a, b): # a = 5, b = 10
    return a + b

def multiply(a, b):
    return a * b

def divide(a, b):
    return a / b

def percent(a ,b):
    return a % b


"""
# Function declarations
1. defining a function with def
2. A function can and will have arguments
"""
def fix_grammer(s): # arg s = "Joshua are here"
    replace_s = "are"
    replace_s_with = "is"
    print(s)

# DRY ( do not repeat yourself ), funcitonal programming (functions, classes)
x = 5
y = 10
z = x + y
print(z)
x = 15
y = 20
z = x + y
print(z)



print(z)
    
# calling a function    


# var declarations
a = 10 # assigns memeory space (container )  # datatype varname = assign; int a = 10;
a = "Joshua" # memory space to store it
b = "S"

# fruits
m = "Mango"
o = "Orange"
g = "Grapes"
f = "fig"
e = "ele.."
c = "c...."

# fruits is a list which contains elements of different types
# list is an array like python object that can contain strings and integers and object (come back to this later)
# accessing the values of a list - indexing -> fruits[0] fruits[1]
fruits = ["Mango", "Orange", "Grape", "Fig", "Apple", "Mosambi", "Avacado"]


# datastructures
# what is an Array ?
# arrays are group of data that share sequential memeory space
# list - Array of values
# tuple - Array of values
# dict - hash tables


# looping or Iterations
# for
# while <conditional statement> ? true or false
    # checks the condition
    # executs the statemetns 
    # cecks the conditiond
    
    # 1 > 0
    # True
    
    # 1. 0 <= 7
    # 2. 1 <= 7
    # 3. 2 <= 7
    # 
    # 6 < 7

    
c = 0
n = len(fruits) # 7
while c < n: # check the condition 0 <= 3, 1 <= 3, 2 <= 3, 3 <= 3, 4 <= 3?
    print('Fruit::' + fruits[c]) # c = 0
    c += 1 # c = 1 increments the value # c = 4
    print(c)
    
# for each fruit in fruits container
# give me a fruit on each iteration

for fruit in fruits:
    print('Fruit::' + fruit)
    
# c = 0
# 'Fruit::' + fruits[c] # __add__ magic func
# c += 1
# 'Fruit::' + fruits[c] # __add__ magic func
# c += 1
# 'Fruit::' + fruits[c] # __add__ magic func
# Out:
# 15
# 35
# 35
# Fruit::Mango
# 1
# Fruit::Orange
# 2
# Fruit::Grape
# 3
# Fruit::Fig
# 4
# Fruit::Apple
# 5
# Fruit::Mosambi
# 6
# Fruit::Avacado
# 7
# Fruit::Mango
# Fruit::Orange
# Fruit::Grape
# Fruit::Fig
# Fruit::Apple
# Fruit::Mosambi
# Fruit::Avacado
