# %%
# Configurations

FORMAT_TYPE = '.yml'
SOURCE_DIR = '/Users/jokrishnan/Downloads/FreshserviceApp (translations) (14)'
# DEST_DIR = '/Users/jokrishnan/projects/itildesk/frontend/translations'
DEST_DIR = '/Users/jokrishnan/projects/itildesk/config/locales'
# ITILDESK_DIR = '/Users/jokrishnan/projects/itildesk/config/locales'
REMOVE_KEYS_FROM_SOURCE = []
UPDATE_KEYS_FROM_JSON = [{
    'json_key': 'fs.common.asset_tag',
    'yml_key': 'ci_type_fields.default_asset_tag'
}, {
    'json_key': 'fs.common.impact',
    'yml_key': 'ci_type_fields.default_impact'
},  {
    'json_key': 'fs.common.display_name',
    'yml_key': 'ci_type_fields.default_display_name'
}]
RENAME_JSON_KEY_LIST = [
    { 'from': 'fs.service_request.asset_tag', 'to': 'fs.common.asset_tag' },
    { 'from': 'fs.service_request.asset_tag', 'to': 'fs.common.asset_tag' }
]

DELETE_KEYS_FROM_JSON = [
    'fs.assets.list.name',
    'fs.assets.list.region',
    'fs.assets.list.cloud_last_audit_date',
    'fs.assets.list.cd_availability_zone'
]

COPY_JSON_KEYS = [
    'fs.common.reset_filter'
]

# %%
# After Updating this Restart & Run All

import os
import json

class GenerateFileList(object):
    
    LANG_MAP = {
        'lv': 'lv-LV', 'es-ES': 'es-LA', 'es-MX': 'es', 'no': 'nb-NO', 'ja': 'ja-JP', 'ru': 'ru-RU', 'cy': 'cy-GB'
    }
    
    def __init__(self, source, dest, overwrite = 1, file_format = '.json'):
        self.source_dir = source
        self.dest_dir = dest
        self.overwrite = overwrite
        self.file_format = file_format
        self.data = []
        
    def get_file_path(self, _dir, lang_file):
        return f'{_dir}/{lang_file}{self.file_format}'
    
    def get_file_list(self, reload = True):
        
        for cur_dir, _, file_name in os.walk(self.source_dir):
            lang_file = cur_dir.split('/')[-1]
            if self.source_dir.split('/')[-1] == lang_file:
                continue
                
            source = f'{self.source_dir}/{lang_file}/{file_name[0]}'
            dest = f'{self.dest_dir}/{self.LANG_MAP.get(lang_file, lang_file)}{self.file_format}'

            self.data.append({
                'source': source,
                'dest': dest,
                'overwrite': self.overwrite
            })
            
        return self.data
    
    def remove_keys(self, _typ, keys):
        for d in self.data:
            f = d[_typ]
            lang = f.split('/')[-1].split('.')[0]
            with open(f, 'r') as _f:
                data = JSONSerializer(_f.read()).content
                del data['fs']['common']['module_views']['default_views']['archived_tickets']
                del data['fs']['common']['export_fields']["asset"]
            with open(f, 'w') as _f:
                _f.write(JSONSerializer().content_dump(lang, False, data, ensure_ascii=False))
                

def calc_indent(key): return len(key.split('.')) * 2

def nested_dict_extract(prefix_path, content, indent = None):
    for i, p in enumerate(prefix_path.split('.')):
        try:
            if indent is None:
                content = content[p]
            else:
                content = content[(p, i * indent)]
        except:
            if p in content: return content[p]
            print(p, 'error', indent)
    return content

def get_parent_path(path):
    return '.'.join(path.split('.')[:-1]), path.split('.')[-1]

# %%
print('SOURCE_DIR', SOURCE_DIR)
file_list = GenerateFileList(
    SOURCE_DIR,
    DEST_DIR,
    1, # dry run
    file_format=FORMAT_TYPE
)

input_file_list = file_list.get_file_list()

if len(REMOVE_KEYS_FROM_SOURCE):
    # Remove any keys if necessary
    file_list.remove_keys('source', REMOVE_KEYS_FROM_SOURCE)

# input_file_list = [{
#   'source': '/Users/jokrishnan/Downloads/Latest-en.json',
#   'dest' : '/Users/jokrishnan/projects/itildesk/frontend/translations/fi.json',
#   'overwrite': 1
# }]

input_file_list
# Out:
# SOURCE_DIR /Users/jokrishnan/Downloads/FreshserviceApp (translations) (14)
# [{'source': '/Users/jokrishnan/Downloads/FreshserviceApp (translations) (14)/sl/03-04-2024_FS-141438_bnb.yml',
#   'dest': '/Users/jokrishnan/projects/itildesk/config/locales/sl.yml',
#   'overwrite': 1},
#  {'source': '/Users/jokrishnan/Downloads/FreshserviceApp (translations) (14)/sk/03-04-2024_FS-141438_bnb.yml',
#   'dest': '/Users/jokrishnan/projects/itildesk/config/locales/sk.yml',
#   'overwrite': 1},
#  {'source': '/Users/jokrishnan/Downloads/FreshserviceApp (translations) (14)/pl/03-04-2024_FS-141438_bnb.yml',
#   'dest': '/Users/jokrishnan/projects/itildesk/config/locales/pl.yml',
#   'overwrite': 1},
#  {'source': '/Users/jokrishnan/Downloads/FreshserviceApp (translations) (14)/vi/03-04-2024_FS-141438_bnb.yml',
#   'dest': '/Users/jokrishnan/projects/itildesk/config/locales/vi.yml',
#   'overwrite': 1},
#  {'source': '/Users/jokrishnan/Downloads/FreshserviceApp (translations) (14)/he/03-04-2024_FS-141438_bnb.yml',
#   'dest': '/Users/jokrishnan/projects/itildesk/config/locales/he.yml',
#   'overwrite': 1},
#  {'source': '/Users/jokrishnan/Downloads/FreshserviceApp (translations) (14)/es-ES/03-04-2024_FS-141438_bnb.yml',
#   'dest': '/Users/jokrishnan/projects/itildesk/config/locales/es-LA.yml',
#   'overwrite': 1},
#  {'source': '/Users/jokrishnan/Downloads/FreshserviceApp (translations) (14)/da/03-04-2024_FS-141438_bnb.yml',
#   'dest': '/Users/jokrishnan/projects/itildesk/config/locales/da.yml',
#   'overwrite': 1},
#  {'source': '/Users/jokrishnan/Downloads/FreshserviceApp (translations) (14)/no/03-04-2024_FS-141438_bnb.yml',
#   'dest': '/Users/jokrishnan/projects/itildesk/config/locales/nb-NO.yml',
#   'overwrite': 1},
#  {'source': '/Users/jokrishnan/Downloads/FreshserviceApp (translations) (14)/ja/03-04-2024_FS-141438_bnb.yml',
#   'dest': '/Users/jokrishnan/projects/itildesk/config/locales/ja-JP.yml',
#   'overwrite': 1},
#  {'source': '/Users/jokrishnan/Downloads/FreshserviceApp (translations) (14)/lv/03-04-2024_FS-141438_bnb.yml',
#   'dest': '/Users/jokrishnan/projects/itildesk/config/locales/lv-LV.yml',
#   'overwrite': 1},
#  {'source': '/Users/jokrishnan/Downloads/FreshserviceApp (translations) (14)/it/03-04-2024_FS-141438_bnb.yml',
#   'dest': '/Users/jokrishnan/projects/itildesk/config/locales/it.yml',
#   'overwrite': 1},
#  {'source': '/Users/jokrishnan/Downloads/FreshserviceApp (translations) (14)/ca/03-04-2024_FS-141438_bnb.yml',
#   'dest': '/Users/jokrishnan/projects/itildesk/config/locales/ca.yml',
#   'overwrite': 1},
#  {'source': '/Users/jokrishnan/Downloads/FreshserviceApp (translations) (14)/cs/03-04-2024_FS-141438_bnb.yml',
#   'dest': '/Users/jokrishnan/projects/itildesk/config/locales/cs.yml',
#   'overwrite': 1},
#  {'source': '/Users/jokrishnan/Downloads/FreshserviceApp (translations) (14)/es-MX/03-04-2024_FS-141438_bnb.yml',
#   'dest': '/Users/jokrishnan/projects/itildesk/config/locales/es.yml',
#   'overwrite': 1},
#  {'source': '/Users/jokrishnan/Downloads/FreshserviceApp (translations) (14)/ru/03-04-2024_FS-141438_bnb.yml',
#   'dest': '/Users/jokrishnan/projects/itildesk/config/locales/ru-RU.yml',
#   'overwrite': 1},
#  {'source': '/Users/jokrishnan/Downloads/FreshserviceApp (translations) (14)/ro/03-04-2024_FS-141438_bnb.yml',
#   'dest': '/Users/jokrishnan/projects/itildesk/config/locales/ro.yml',
#   'overwrite': 1},
#  {'source': '/Users/jokrishnan/Downloads/FreshserviceApp (translations) (14)/zh-CN/03-04-2024_FS-141438_bnb.yml',
#   'dest': '/Users/jokrishnan/projects/itildesk/config/locales/zh-CN.yml',
#   'overwrite': 1},
#  {'source': '/Users/jokrishnan/Downloads/FreshserviceApp (translations) (14)/uk/03-04-2024_FS-141438_bnb.yml',
#   'dest': '/Users/jokrishnan/projects/itildesk/config/locales/uk.yml',
#   'overwrite': 1},
#  {'source': '/Users/jokrishnan/Downloads/FreshserviceApp (translations) (14)/pt-PT/03-04-2024_FS-141438_bnb.yml',
#   'dest': '/Users/jokrishnan/projects/itildesk/config/locales/pt-PT.yml',
#   'overwrite': 1},
#  {'source': '/Users/jokrishnan/Downloads/FreshserviceApp (translations) (14)/zh-TW/03-04-2024_FS-141438_bnb.yml',
#   'dest': '/Users/jokrishnan/projects/itildesk/config/locales/zh-TW.yml',
#   'overwrite': 1},
#  {'source': '/Users/jokrishnan/Downloads/FreshserviceApp (translations) (14)/ar/03-04-2024_FS-141438_bnb.yml',
#   'dest': '/Users/jokrishnan/projects/itildesk/config/locales/ar.yml',
#   'overwrite': 1},
#  {'source': '/Users/jokrishnan/Downloads/FreshserviceApp (translations) (14)/hr/03-04-2024_FS-141438_bnb.yml',
#   'dest': '/Users/jokrishnan/projects/itildesk/config/locales/hr.yml',
#   'overwrite': 1},
#  {'source': '/Users/jokrishnan/Downloads/FreshserviceApp (translations) (14)/pt-BR/03-04-2024_FS-141438_bnb.yml',
#   'dest': '/Users/jokrishnan/projects/itildesk/config/locales/pt-BR.yml',
#   'overwrite': 1},
#  {'source': '/Users/jokrishnan/Downloads/FreshserviceApp (translations) (14)/hu/03-04-2024_FS-141438_bnb.yml',
#   'dest': '/Users/jokrishnan/projects/itildesk/config/locales/hu.yml',
#   'overwrite': 1},
#  {'source': '/Users/jokrishnan/Downloads/FreshserviceApp (translations) (14)/nl/03-04-2024_FS-141438_bnb.yml',
#   'dest': '/Users/jokrishnan/projects/itildesk/config/locales/nl.yml',
#   'overwrite': 1},
#  {'source': '/Users/jokrishnan/Downloads/FreshserviceApp (translations) (14)/de/03-04-2024_FS-141438_bnb.yml',
#   'dest': '/Users/jokrishnan/projects/itildesk/config/locales/de.yml',
#   'overwrite': 1},
#  {'source': '/Users/jokrishnan/Downloads/FreshserviceApp (translations) (14)/ko/03-04-2024_FS-141438_bnb.yml',
#   'dest': '/Users/jokrishnan/projects/itildesk/config/locales/ko.yml',
#   'overwrite': 1},
#  {'source': '/Users/jokrishnan/Downloads/FreshserviceApp (translations) (14)/fi/03-04-2024_FS-141438_bnb.yml',
#   'dest': '/Users/jokrishnan/projects/itildesk/config/locales/fi.yml',
#   'overwrite': 1},
#  {'source': '/Users/jokrishnan/Downloads/FreshserviceApp (translations) (14)/id/03-04-2024_FS-141438_bnb.yml',
#   'dest': '/Users/jokrishnan/projects/itildesk/config/locales/id.yml',
#   'overwrite': 1},
#  {'source': '/Users/jokrishnan/Downloads/FreshserviceApp (translations) (14)/fr/03-04-2024_FS-141438_bnb.yml',
#   'dest': '/Users/jokrishnan/projects/itildesk/config/locales/fr.yml',
#   'overwrite': 1},
#  {'source': '/Users/jokrishnan/Downloads/FreshserviceApp (translations) (14)/sv-SE/03-04-2024_FS-141438_bnb.yml',
#   'dest': '/Users/jokrishnan/projects/itildesk/config/locales/sv-SE.yml',
#   'overwrite': 1},
#  {'source': '/Users/jokrishnan/Downloads/FreshserviceApp (translations) (14)/et/03-04-2024_FS-141438_bnb.yml',
#   'dest': '/Users/jokrishnan/projects/itildesk/config/locales/et.yml',
#   'overwrite': 1},
#  {'source': '/Users/jokrishnan/Downloads/FreshserviceApp (translations) (14)/cy/03-04-2024_FS-141438_bnb.yml',
#   'dest': '/Users/jokrishnan/projects/itildesk/config/locales/cy-GB.yml',
#   'overwrite': 1},
#  {'source': '/Users/jokrishnan/Downloads/FreshserviceApp (translations) (14)/th/03-04-2024_FS-141438_bnb.yml',
#   'dest': '/Users/jokrishnan/projects/itildesk/config/locales/th.yml',
#   'overwrite': 1},
#  {'source': '/Users/jokrishnan/Downloads/FreshserviceApp (translations) (14)/tr/03-04-2024_FS-141438_bnb.yml',
#   'dest': '/Users/jokrishnan/projects/itildesk/config/locales/tr.yml',
#   'overwrite': 1}]

# %%
# Execute the command to start the merge two files o same type

cmd = f'python3 ../exec_translation.py --dry_run 0 merge --file_list \'{json.dumps(input_file_list)}\' --overwrite 1'

# !{cmd}
# Out:
# Merging file file /Users/jokrishnan/Downloads/FreshserviceApp (translations) (14)/sl/03-04-2024_FS-141438_bnb.yml with /Users/jokrishnan/projects/itildesk/config/locales/sl.yml
# Merging file file /Users/jokrishnan/Downloads/FreshserviceApp (translations) (14)/sk/03-04-2024_FS-141438_bnb.yml with /Users/jokrishnan/projects/itildesk/config/locales/sk.yml
# Merging file file /Users/jokrishnan/Downloads/FreshserviceApp (translations) (14)/pl/03-04-2024_FS-141438_bnb.yml with /Users/jokrishnan/projects/itildesk/config/locales/pl.yml
# Merging file file /Users/jokrishnan/Downloads/FreshserviceApp (translations) (14)/vi/03-04-2024_FS-141438_bnb.yml with /Users/jokrishnan/projects/itildesk/config/locales/vi.yml
# Merging file file /Users/jokrishnan/Downloads/FreshserviceApp (translations) (14)/he/03-04-2024_FS-141438_bnb.yml with /Users/jokrishnan/projects/itildesk/config/locales/he.yml
# Merging file file /Users/jokrishnan/Downloads/FreshserviceApp (translations) (14)/es-ES/03-04-2024_FS-141438_bnb.yml with /Users/jokrishnan/projects/itildesk/config/locales/es-LA.yml
# Merging file file /Users/jokrishnan/Downloads/FreshserviceApp (translations) (14)/da/03-04-2024_FS-141438_bnb.yml with /Users/jokrishnan/projects/itildesk/config/locales/da.yml
# Merging file file /Users/jokrishnan/Downloads/FreshserviceApp (translations) (14)/no/03-04-2024_FS-141438_bnb.yml with /Users/jokrishnan/projects/itildesk/config/locales/nb-NO.yml
# Merging file file /Users/jokrishnan/Downloads/FreshserviceApp (translations) (14)/ja/03-04-2024_FS-141438_bnb.yml with /Users/jokrishnan/projects/itildesk/config/locales/ja-JP.yml
# Merging file file /Users/jokrishnan/Downloads/FreshserviceApp (translations) (14)/lv/03-04-2024_FS-141438_bnb.yml with /Users/jokrishnan/projects/itildesk/config/locales/lv-LV.yml
# Merging file file /Users/jokrishnan/Downloads/FreshserviceApp (translations) (14)/it/03-04-2024_FS-141438_bnb.yml with /Users/jokrishnan/projects/itildesk/config/locales/it.yml
# Merging file file /Users/jokrishnan/Downloads/FreshserviceApp (translations) (14)/ca/03-04-2024_FS-141438_bnb.yml with /Users/jokrishnan/projects/itildesk/config/locales/ca.yml
# Merging file file /Users/jokrishnan/Downloads/FreshserviceApp (translations) (14)/cs/03-04-2024_FS-141438_bnb.yml with /Users/jokrishnan/projects/itildesk/config/locales/cs.yml
# Merging file file /Users/jokrishnan/Downloads/FreshserviceApp (translations) (14)/es-MX/03-04-2024_FS-141438_bnb.yml with /Users/jokrishnan/projects/itildesk/config/locales/es.yml
# Merging file file /Users/jokrishnan/Downloads/FreshserviceApp (translations) (14)/ru/03-04-2024_FS-141438_bnb.yml with /Users/jokrishnan/projects/itildesk/config/locales/ru-RU.yml
# Merging file file /Users/jokrishnan/Downloads/FreshserviceApp (translations) (14)/ro/03-04-2024_FS-141438_bnb.yml with /Users/jokrishnan/projects/itildesk/config/locales/ro.yml
# Merging file file /Users/jokrishnan/Downloads/FreshserviceApp (translations) (14)/zh-CN/03-04-2024_FS-141438_bnb.yml with /Users/jokrishnan/projects/itildesk/config/locales/zh-CN.yml
# Merging file file /Users/jokrishnan/Downloads/FreshserviceApp (translations) (14)/uk/03-04-2024_FS-141438_bnb.yml with /Users/jokrishnan/projects/itildesk/config/locales/uk.yml
# Merging file file /Users/jokrishnan/Downloads/FreshserviceApp (translations) (14)/pt-PT/03-04-2024_FS-141438_bnb.yml with /Users/jokrishnan/projects/itildesk/config/locales/pt-PT.yml
# Merging file file /Users/jokrishnan/Downloads/FreshserviceApp (translations) (14)/zh-TW/03-04-2024_FS-141438_bnb.yml with /Users/jokrishnan/projects/itildesk/config/locales/zh-TW.yml
# Merging file file /Users/jokrishnan/Downloads/FreshserviceApp (translations) (14)/ar/03-04-2024_FS-141438_bnb.yml with /Users/jokrishnan/projects/itildesk/config/locales/ar.yml
# Merging file file /Users/jokrishnan/Downloads/FreshserviceApp (translations) (14)/hr/03-04-2024_FS-141438_bnb.yml with /Users/jokrishnan/projects/itildesk/config/locales/hr.yml
# Merging file file /Users/jokrishnan/Downloads/FreshserviceApp (translations) (14)/pt-BR/03-04-2024_FS-141438_bnb.yml with /Users/jokrishnan/projects/itildesk/config/locales/pt-BR.yml
# Merging file file /Users/jokrishnan/Downloads/FreshserviceApp (translations) (14)/hu/03-04-2024_FS-141438_bnb.yml with /Users/jokrishnan/projects/itildesk/config/locales/hu.yml
# Merging file file /Users/jokrishnan/Downloads/FreshserviceApp (translations) (14)/nl/03-04-2024_FS-141438_bnb.yml with /Users/jokrishnan/projects/itildesk/config/locales/nl.yml
# Merging file file /Users/jokrishnan/Downloads/FreshserviceApp (translations) (14)/de/03-04-2024_FS-141438_bnb.yml with /Users/jokrishnan/projects/itildesk/config/locales/de.yml
# Merging file file /Users/jokrishnan/Downloads/FreshserviceApp (translations) (14)/ko/03-04-2024_FS-141438_bnb.yml with /Users/jokrishnan/projects/itildesk/config/locales/ko.yml
# Merging file file /Users/jokrishnan/Downloads/FreshserviceApp (translations) (14)/fi/03-04-2024_FS-141438_bnb.yml with /Users/jokrishnan/projects/itildesk/config/locales/fi.yml
# Merging file file /Users/jokrishnan/Downloads/FreshserviceApp (translations) (14)/id/03-04-2024_FS-141438_bnb.yml with /Users/jokrishnan/projects/itildesk/config/locales/id.yml
# Merging file file /Users/jokrishnan/Downloads/FreshserviceApp (translations) (14)/fr/03-04-2024_FS-141438_bnb.yml with /Users/jokrishnan/projects/itildesk/config/locales/fr.yml
# Merging file file /Users/jokrishnan/Downloads/FreshserviceApp (translations) (14)/sv-SE/03-04-2024_FS-141438_bnb.yml with /Users/jokrishnan/projects/itildesk/config/locales/sv-SE.yml
# Merging file file /Users/jokrishnan/Downloads/FreshserviceApp (translations) (14)/et/03-04-2024_FS-141438_bnb.yml with /Users/jokrishnan/projects/itildesk/config/locales/et.yml
# Merging file file /Users/jokrishnan/Downloads/FreshserviceApp (translations) (14)/cy/03-04-2024_FS-141438_bnb.yml with /Users/jokrishnan/projects/itildesk/config/locales/cy-GB.yml
# Merging file file /Users/jokrishnan/Downloads/FreshserviceApp (translations) (14)/th/03-04-2024_FS-141438_bnb.yml with /Users/jokrishnan/projects/itildesk/config/locales/th.yml
# Merging file file /Users/jokrishnan/Downloads/FreshserviceApp (translations) (14)/tr/03-04-2024_FS-141438_bnb.yml with /Users/jokrishnan/projects/itildesk/config/locales/tr.yml

# %%
# Update YML Files from json Keys
import copy
from deepdiff import extract
from file_obj import FileObject
from serializers import CustomSerializer

if len(UPDATE_KEYS_FROM_JSON):
    keys = copy.deepcopy(UPDATE_KEYS_FROM_JSON)
    os.environ['clear_file_cache'] = '1'
    
    # get keys from json file
    for d in input_file_list:
        source_file = FileObject(d['source'])
        source_data = source_file.open_file(preserve_indentation = True)
        source_key = source_file.file_type + '_key'
        
        dest_file = FileObject(d['dest'])
        dest_data = dest_file.open_file(preserve_indentation = True)
        dest_key = dest_file.file_type + '_key'
        lang = d['dest'].split('/')[-1].split('.')[0]
        
        print("Updating for language - ", lang)
        
        for key in keys:
            k = f"{lang}.{key[dest_key]}"
            key_path = ".".join(k.split('.')[:-1])
            parent = nested_dict_extract(key_path, dest_data, 2)
            
            key_to_update = key[dest_key].split('.')[-1]
            parent[key_to_update] = (nested_dict_extract(key[source_key], source_data), calc_indent(key_path))

        serializer = CustomSerializer(dest_file.file_type)
        dest_file.write_file(serializer.content_dump(None, False, dest_data, ensure_ascii=False))

# %%
# Update JSON keys from YML Files

import copy
from deepdiff import extract
from file_obj import FileObject
from serializers import CustomSerializer

if len(UPDATE_KEYS_FROM_JSON):
    keys = copy.deepcopy(UPDATE_KEYS_FROM_JSON)
    os.environ['clear_file_cache'] = '1'
    
    # get keys from json file
    for d in input_file_list:
        source_file = FileObject(d['source'])
        source_data = source_file.open_file(preserve_indentation = True)
        source_key = source_file.file_type + '_key'
        
        dest_file = FileObject(d['dest'])
        dest_data = dest_file.open_file(preserve_indentation = True)
        dest_key = dest_file.file_type + '_key'
        lang = d['dest'].split('/')[-1].split('.')[0]
        
        print("Processing language - ", lang)
        try:
            for key in keys:
                k = f"{lang}.{key[source_key]}"
                print('\tSource Key::', k)
                print('\tDest Key::', key[dest_key])
                parent_path, key_to_update = get_parent_path(key[dest_key])
                dest_parent = nested_dict_extract(parent_path, dest_data)
                dest_parent[key_to_update] = nested_dict_extract(k, source_data, 2)[0]
        except:
            print("Failed Processing language - ", lang)

        serializer = CustomSerializer(dest_file.file_type)
        dest_file.write_file(serializer.content_dump(None, False, dest_data, ensure_ascii=False))

# %%
nested_dict_extract('sl.ci_type_fields.default_asset_tag', source_data, 2)

# %%
# GET Missing keys from json

from yml_parser import YMLParser


# for f in list(map(lambda x : x['dest'], input_file_list)):

lang_file = YMLParser(preserve_indentation = True)
lang_file.load('/Users/jokrishnan/projects/itildesk/config/locales/fi.yml')


en_file = YMLParser(debug_mode=False)
en_file.load('/Users/jokrishnan/projects/itildesk/config/locales/en.yml')

def get_missing_keys(en_data, lang_data, parent_key = 'fi', remove_keys = []):
    for k, v in lang_data.items():
        key = k[0] if type(k) is tuple else k
        
        if (
            (key in en_data) or 
            ((key + ' ') in en_data) or 
            (key.replace("'", "") in en_data) or
            (key.replace('"', "") in en_data)
        ):
            if type(v) is dict:
                get_missing_keys(en_data[key], v, parent_key + '.' + key)
        else:
            if key == 'bo_overall_field_max_limit':
                print(en_data.keys())
                raise ValueError
            p_key = parent_key + '.' + key
            remove_keys.append(p_key)
    return remove_keys                                                    

remove_keys = get_missing_keys(en_file.data['en'], lang_file.data[('fi', 0)])

for k in remove_keys:
    parent_path, key = get_parent_path(k)
    d = nested_dict_extract(parent_path, lang_file.data, 2)

    if key in d:
        del d[key]
    
    elif (key, calc_indent(k.replace('fi.', ''))) in d:
        del d[(key, calc_indent(k.replace('fi.', '')))]
    
    else:
        print('unable to remove key', key, parent_path)

remove_keys
# Out:
# ['fi.will_paginate.problem_association',
#  'fi.ticket_fields.form_fields.first_response_date',
#  'fi.ticket_fields.form_fields.contact_location',
#  'fi.ticket_fields.form_fields.contact_vip',
#  'fi.integrations.google_calendar.form.google_calendar_settings_info',
#  'fi.integrations.google_calendar.form.google_calendar_settings',
#  'fi.mailer_notifier.security_notification.data_export.warning_note',
#  'fi.itil.change.change_added_as_watcher',
#  'fi.itil.change.change_removed_as_watcher',
#  'fi.itil.change.list_views.monitored_by',
#  'fi.tfs.info',
#  'fi.audit_log.agent.description',
#  'fi.audit_log.agent.description_audit_enhanced.company_update',
#  'fi.js_translations.audit_logs.event_types.sla_policy',
#  'fi.js_translations.user_onboarding.title',
#  'fi.js_translations.workspace.header.learn_more',
#  'fi.js_translations.dynamic_banner.resend_activation_mail',
#  'fi.js_translations.dynamic_banner.activation_email_reminder',
#  'fi.answer_bot.templates.account',
#  'fi.answer_bot.templates.select_group_team',
#  'fi.answer_bot.templates.pick_option',
#  'fi.answer_bot.templates.select_fs_group',
#  'fi.answer_bot.templates.select_team_channel',
#  'fi.answer_bot.templates.notify_priority',
#  'fi.answer_bot.templates.pick_channel',
#  'fi.answer_bot.templates.associate_group_to_channel',
#  'fi.answer_bot.templates.teams_not_found',
#  'fi.answer_bot.templates.all_priorities',
#  'fi.answer_bot.templates.group_dissociate_confirmation',
#  'fi.answer_bot.templates.group_dissociate_success',
#  'fi.answer_bot.templates.unable_to_perform',
#  'fi.answer_bot.templates.group_channel_mapping_exist_message',
#  'fi.answer_bot.templates.associate_freshservice_groups_with_teams_message',
#  'fi.answer_bot.templates.only_channels_with_bot_added_message',
#  'fi.answer_bot.templates.associate',
#  'fi.answer_bot.templates.dissociate',
#  'fi.answer_bot.templates.have_an_idea_suggestion',
#  'fi.answer_bot.templates.tell_us',
#  'fi.answer_bot.templates.group_channel_association_info_message',
#  'fi.answer_bot.templates.team_channels_already_assigned',
#  'fi.answer_bot.templates.edit_association_success',
#  'fi.answer_bot.templates.edit_associations_title',
#  'fi.answer_bot.templates.settings_tab_admin_message',
#  'fi.answer_bot.templates.settings_tab_non_admin_message',
#  'fi.instance_management.configurations_label.sla_policy_configuration']

# %%
yml_str = lang_file.dump(file_path = '/Users/jokrishnan/projects/itildesk/config/locales/fi.yml')

# %%
from yml_parser import YMLParser

# en_file = YMLParser(debug_mode=True)
# en_file.load('/Users/jokrishnan/projects/itildesk/config/locales/en.yml')
s = 'bo_overall_field_max_limit : You have reached the overall field limit for this custom object'

not re.match(r'^[^ ]+: ', s.strip()) and not re.match(r'^[a-z0-9-_A-Z\/\'\"]+:' + ' ', s.strip())

# %%
# DELETE KEYS FROM JSON
if len(DELETE_KEYS_FROM_JSON):
    os.environ['clear_file_cache'] = '1'
    for f in map(lambda x : x['dest'], input_file_list):
        file = FileObject(f)
        data = file.open_file()
        for key in DELETE_KEYS_FROM_JSON:
            value = nested_dict_extract(key, data)
            parent_path, k = get_parent_path(key)
            parent_data = nested_dict_extract(parent_path, data)
            del parent_data[k]
        serializer = CustomSerializer(file.file_type)
        file.write_file(serializer.content_dump(None, False, data, ensure_ascii=False))

# %%
from file_obj import FileObject
from serializers import CustomSerializer

# Rename Key
# Eg: fs.assets.export_assets -> fs.common.export_fields.asset
if len(RENAME_JSON_KEY_LIST):
    os.environ['clear_file_cache'] = '1'
    for f in list(map(lambda x : x['dest'], input_file_list)):
        file = FileObject(f)
        data = file.open_file()
        for key in RENAME_JSON_KEY_LIST:
            value = nested_dict_extract(key['from'], data)
            parent_path, k = get_parent_path(key['from'])
            parent_data = nested_dict_extract(parent_path, data)
#             del parent_data[k]
            parent_path, k = get_parent_path(key['to'])
            parent_data = nested_dict_extract(parent_path, data)
            parent_data[k] = value
        serializer = CustomSerializer(file.file_type)
        file.write_file(serializer.content_dump(None, False, data, ensure_ascii=False))
        print('Writed to file', f)

# %%
from file_obj import FileObject
from serializers import CustomSerializer

# Rename Key
# Eg: fs.assets.export_assets -> fs.common.export_fields.asset
if len(COPY_JSON_KEYS):
    os.environ['clear_file_cache'] = '1'
    for obj in input_file_list:
        dest_file = FileObject(obj['dest'])
        source_file = FileObject(obj['source'])
        
        dest_data = dest_file.open_file()
        source_data = source_file.open_file()
        
        dataset = {}
        for key in COPY_JSON_KEYS:
            value = nested_dict_extract(key, source_data)
            parent_path, k = get_parent_path(key)
            parent_data = nested_dict_extract(parent_path, dest_data)
            parent_data[k] = value
            
        serializer = CustomSerializer(dest_file.file_type)
        dest_file.write_file(serializer.content_dump(None, False, dest_data, ensure_ascii=False))
        print('Writed to file', dest_file.file_path)

# %%
lang_file.data[('fi', 0)][('will_paginate', 2)]
